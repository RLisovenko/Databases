# %% [markdown]
# ####         Lab m1_L1 : SQL select
# #####        LiR
# ######       13-01-2026
# ######       https://github.com/simonw/datasette

# %%
import os
sCurPath = os.getcwd()
print(sCurPath)
# Out:
# c:\SourceCode\PSC\2025\coursera\2_SQL_DataSceince

# %%
# !which python
# !python --version
#!python -m pip install datasett
# Out:
# 'which' is not recognized as an internal or external command,
# operable program or batch file.
# Python 3.11.14
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: Ignored the following versions that require a different python version: 0.0.1 Requires-Python ==3.9.2
# ERROR: Could not find a version that satisfies the requirement datasett (from versions: none)
# ERROR: No matching distribution found for datasett

# %%
# MAC
# brew install datasette
# !pip install datasette
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting datasette
#   Downloading datasette-0.65.2-py3-none-any.whl.metadata (8.1 kB)
# Collecting asgiref>=3.2.10 (from datasette)
#   Downloading asgiref-3.11.0-py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: click>=7.1.1 in c:\dev_soft\anaconda3_2023\lib\site-packages (from datasette) (8.1.8)
# Collecting click-default-group>=1.2.3 (from datasette)
#   Downloading click_default_group-1.2.4-py2.py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: Jinja2>=2.10.3 in c:\dev_soft\anaconda3_2023\lib\site-packages (from datasette) (3.1.6)
# Collecting hupper>=1.9 (from datasette)
#   Downloading hupper-1.12.1-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: httpx>=0.20 in c:\dev_soft\anaconda3_2023\lib\site-packages (from datasette) (0.28.1)
# Requirement already satisfied: pluggy>=1.0 in c:\dev_soft\anaconda3_2023\lib\site-packages (from datasette) (1.5.0)
# Collecting uvicorn>=0.11 (from datasette)
#   Downloading uvicorn-0.40.0-py3-none-any.whl.metadata (6.7 kB)
# Collecting aiofiles>=0.4 (from datasette)
#   Downloading aiofiles-25.1.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting janus>=0.6.2 (from datasette)
#   Downloading janus-2.0.0-py3-none-any.whl.metadata (5.3 kB)
# Collecting asgi-csrf>=0.9 (from datasette)
#   Downloading asgi_csrf-0.11-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: PyYAML>=5.3 in c:\dev_soft\anaconda3_2023\lib\site-packages (from datasette) (6.0.2)
# Collecting mergedeep>=1.1.1 (from datasette)
#   Downloading mergedeep-1.3.4-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: itsdangerous>=1.1 in c:\dev_soft\anaconda3_2023\lib\site-packages (from datasette) (2.2.0)
# Requirement already satisfied: setuptools in c:\dev_soft\anaconda3_2023\lib\site-packages (from datasette) (80.9.0)
# Requirement already satisfied: pip in c:\dev_soft\anaconda3_2023\lib\site-packages (from datasette) (25.2)
# Requirement already satisfied: platformdirs>=2.1.0 in c:\dev_soft\anaconda3_2023\lib\site-packages (from datasette) (4.3.7)
# Requirement already satisfied: typing_extensions>=4.0.0 in c:\dev_soft\anaconda3_2023\lib\site-packages (from datasette) (4.15.0)
# Collecting flexcache>=0.3 (from datasette)
#   Downloading flexcache-0.3-py3-none-any.whl.metadata (7.0 kB)
# Collecting flexparser>=0.3 (from datasette)
#   Downloading flexparser-0.4-py3-none-any.whl.metadata (18 kB)
# Collecting python-multipart>=0.0.13 (from asgi-csrf>=0.9->datasette)
#   Downloading python_multipart-0.0.21-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: colorama in c:\dev_soft\anaconda3_2023\lib\site-packages (from click>=7.1.1->datasette) (0.4.6)
# Requirement already satisfied: anyio in c:\dev_soft\anaconda3_2023\lib\site-packages (from httpx>=0.20->datasette) (4.10.0)
# Requirement already satisfied: certifi in c:\dev_soft\anaconda3_2023\lib\site-packages (from httpx>=0.20->datasette) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\dev_soft\anaconda3_2023\lib\site-packages (from httpx>=0.20->datasette) (1.0.9)
# Requirement already satisfied: idna in c:\dev_soft\anaconda3_2023\lib\site-packages (from httpx>=0.20->datasette) (3.7)
# Requirement already satisfied: h11>=0.16 in c:\dev_soft\anaconda3_2023\lib\site-packages (from httpcore==1.*->httpx>=0.20->datasette) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\dev_soft\anaconda3_2023\lib\site-packages (from Jinja2>=2.10.3->datasette) (3.0.2)
# Requirement already satisfied: sniffio>=1.1 in c:\dev_soft\anaconda3_2023\lib\site-packages (from anyio->httpx>=0.20->datasette) (1.3.0)
# Downloading datasette-0.65.2-py3-none-any.whl (397 kB)
# Downloading aiofiles-25.1.0-py3-none-any.whl (14 kB)
# Downloading asgi_csrf-0.11-py3-none-any.whl (11 kB)
# Downloading asgiref-3.11.0-py3-none-any.whl (24 kB)
# Downloading click_default_group-1.2.4-py2.py3-none-any.whl (4.1 kB)
# Downloading flexcache-0.3-py3-none-any.whl (13 kB)
# Downloading flexparser-0.4-py3-none-any.whl (27 kB)
# Downloading hupper-1.12.1-py3-none-any.whl (22 kB)
# Downloading janus-2.0.0-py3-none-any.whl (12 kB)
# Downloading mergedeep-1.3.4-py3-none-any.whl (6.4 kB)
# Downloading python_multipart-0.0.21-py3-none-any.whl (24 kB)
# Downloading uvicorn-0.40.0-py3-none-any.whl (68 kB)
# Installing collected packages: python-multipart, mergedeep, janus, hupper, flexparser, flexcache, asgiref, aiofiles, uvicorn, click-default-group, asgi-csrf, datasette
#
#    ----------------------------------------  0/12 [python-multipart]
#    ------ ---------------------------------  2/12 [janus]
#    ---------- -----------------------------  3/12 [hupper]
#    ---------- -----------------------------  3/12 [hupper]
#    ------------- --------------------------  4/12 [flexparser]
#    ------------- --------------------------  4/12 [flexparser]
#    ---------------- -----------------------  5/12 [flexcache]
#    -------------------- -------------------  6/12 [asgiref]
#    ----------------------- ----------------  7/12 [aiofiles]
#    ----------------------- ----------------  7/12 [aiofiles]
#    -------------------------- -------------  8/12 [uvicorn]
#    -------------------------- -------------  8/12 [uvicorn]
#    -------------------------- -------------  8/12 [uvicorn]
#    -------------------------- -------------  8/12 [uvicorn]
#    -------------------------- -------------  8/12 [uvicorn]
#    -------------------------- -------------  8/12 [uvicorn]
#    ------------------------------------ --- 11/12 [datasette]
#    ------------------------------------ --- 11/12 [datasette]
#    ------------------------------------ --- 11/12 [datasette]
#    ------------------------------------ --- 11/12 [datasette]
#    ------------------------------------ --- 11/12 [datasette]
#    ------------------------------------ --- 11/12 [datasette]
#    ------------------------------------ --- 11/12 [datasette]
#    ------------------------------------ --- 11/12 [datasette]
#    ------------------------------------ --- 11/12 [datasette]
#    ------------------------------------ --- 11/12 [datasette]
#    ------------------------------------ --- 11/12 [datasette]
#    ------------------------------------ --- 11/12 [datasette]
#    ------------------------------------ --- 11/12 [datasette]
#    ------------------------------------ --- 11/12 [datasette]
#    ------------------------------------ --- 11/12 [datasette]
#    ------------------------------------ --- 11/12 [datasette]
#    ------------------------------------ --- 11/12 [datasette]
#    ------------------------------------ --- 11/12 [datasette]
#    ------------------------------------ --- 11/12 [datasette]
#    ------------------------------------ --- 11/12 [datasette]
#    ------------------------------------ --- 11/12 [datasette]
#    ---------------------------------------- 12/12 [datasette]
#
# Successfully installed aiofiles-25.1.0 asgi-csrf-0.11 asgiref-3.11.0 click-default-group-1.2.4 datasette-0.65.2 flexcache-0.3 flexparser-0.4 hupper-1.12.1 janus-2.0.0 mergedeep-1.3.4 python-multipart-0.0.21 uvicorn-0.40.0
#   WARNING: The script hupper.exe is installed in 'C:\Users\rusla\AppData\Roaming\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script uvicorn.exe is installed in 'C:\Users\rusla\AppData\Roaming\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script datasette.exe is installed in 'C:\Users\rusla\AppData\Roaming\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import datasette
datasette
#SELECT * FROM FilmLocations
# Out:
# <module 'datasette' from 'C:\\Users\\rusla\\AppData\\Roaming\\Python\\Python311\\site-packages\\datasette\\__init__.py'>

# %%
#datasette publish cloudrun database.db
SELECT * FROM FilmLocations;
SELECT Title, ReleaseYear, Locations FROM FilmLocations WHERE ReleaseYear>=2001;
SELECT Locations, FunFacts FROM FilmLocations;
SELECT Locations, FunFacts FROM FilmLocations;
SELECT Title, ReleaseYear, Locations FROM FilmLocations WHERE ReleaseYear<=2000;
SELECT Title, ProductionCompany, Locations, ReleaseYear FROM FilmLocations WHERE Writer<>"James Cameron";
# Out:
#   Cell In[17], line 1
#
#     datasette publish cloudrun database.db
#
#               ^
#
# SyntaxError: invalid syntax

# %%
ds_FilmLocations = datasette['FilmLocations']
# Out:
# ---------------------------------------------------------------------------
#
# TypeError                                 Traceback (most recent call last)
#
# Cell In[13], line 1
#
# ----> 1 ds_FilmLocations = datasette['FilmLocations']
#
#
#
# TypeError: 'module' object is not subscriptable
